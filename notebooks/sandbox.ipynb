# %%
import matplotlib.pyplot as plt
from src.data import OxfordPetsSegmentation

dataset = OxfordPetsSegmentation(root="data/oxford_pets", split="train", transform=None, target_transform=None)
image, mask = dataset[5000]
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.subplot(1, 2, 2)
plt.imshow(mask)

# %%
import matplotlib.pyplot as plt
import random
from src.data import OxfordPetsSegmentation
import torch
from torch.utils.data import DataLoader

num = random.randint(0, 1000)

dataset = OxfordPetsSegmentation(root="data/oxford_pets", split="train", transform=None, target_transform=None, seed=num)
random.shuffle(dataset.samples)
dataset_train = OxfordPetsSegmentation(root="data/oxford_pets", split="train", transform=None, target_transform=None, seed = num)
dataset_val = OxfordPetsSegmentation(root="data/oxford_pets", split="val", transform=None, target_transform=None, seed = num)
dataset_test = OxfordPetsSegmentation(root="data/oxford_pets", split="test", transform=None, target_transform=None, seed = num)

train_image, train_mask = dataset_train[0]
val_image, val_mask = dataset_val[0]
test_image, test_mask = dataset_test[0]

plt.subplot(3, 2, 1)
plt.imshow(train_image)
plt.subplot(3, 2, 2)
plt.imshow(train_mask)
plt.subplot(3, 2, 3)
plt.imshow(val_image)
plt.subplot(3, 2, 4)
plt.imshow(val_mask)
plt.subplot(3, 2, 5)
plt.imshow(test_image)
plt.subplot(3, 2, 6)
plt.imshow(test_mask)

# %%
from src.data import OxfordPetsSegmentation
from src.utils import get_simple_transforms, get_mean_and_std
ds = OxfordPetsSegmentation(root="data/oxford_pets", split="train", transform=get_simple_transforms(), target_transform=get_simple_transforms(), seed=0)
img, mask = ds[0]
print(type(img), type(mask))
# Out:
# <class 'torch.Tensor'> <class 'torch.Tensor'>

# %%
import torch

# check for CUDA
print("CUDA available:", torch.cuda.is_available())
print("CUDA device count:", torch.cuda.device_count())
if torch.cuda.is_available():
    print("CUDA device name:", torch.cuda.get_device_name(0))

# check for MPS (Apple Metal Performance Shaders)
print("MPS available:", torch.backends.mps.is_available())

# default device
device = torch.device("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")
print("Using device:", device)
# Out:
# CUDA available: False
# CUDA device count: 0
# MPS available: True
# Using device: mps
